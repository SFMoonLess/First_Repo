# %% [markdown]
# <a href="https://colab.research.google.com/github/SFMoonLess/First_Repo/blob/main/%D0%A6%D0%A2%D0%9B%D0%A01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования Markdown
# Что нужно сделать:
#
# * 1
# * 2
# * 3
# # Image
# ![An image](https://accounts.hytale.com/images/logo-leaves.webp)
#
# # Table
# 1|2
# -|-
# a|c
# b|d
# # Link
# [A link](https://accounts.hytale.com/images/logo-leaves.webp)
